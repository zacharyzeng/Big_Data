# %%
import pandas as pd

# %%
df = pd.read_csv('1973-UC-Berkeley-Admission-Data-Synthesis-Data.csv')

# %%
a = df['Male-Admitted']
b = df['Male-Denied']
c = df['Female-Admitted']
d = df['Female-Denied']

# %%
df['Male-Ratio'] = df['Male-Admitted'] / (df['Male-Admitted'] + df['Male-Denied'])

# %%
df
# Out:
#   Department  Male-Admitted  Male-Denied  Female-Admitted  Female-Denied  \
# 0          A            512          313               89             19
# 1          B            313          207               17              8
# 2          C            101          205              202            391
# 3          D            138          279              131            244
# 4          E             40          138               94            299
# 5          F             22          351               24            317
#
#    Male-Ratio
# 0    0.620606
# 1    0.601923
# 2    0.330065
# 3    0.330935
# 4    0.224719
# 5    0.058981

# %%
df['Female-Ratio'] = df['Female-Admitted'] / (df['Female-Admitted'] + df['Female-Denied'])

# %%
df
# Out:
#   Department  Male-Admitted  Male-Denied  Female-Admitted  Female-Denied  \
# 0          A            512          313               89             19
# 1          B            313          207               17              8
# 2          C            101          205              202            391
# 3          D            138          279              131            244
# 4          E             40          138               94            299
# 5          F             22          351               24            317
#
#    Male-Ratio  Female-Ratio
# 0    0.620606      0.824074
# 1    0.601923      0.680000
# 2    0.330065      0.340641
# 3    0.330935      0.349333
# 4    0.224719      0.239186
# 5    0.058981      0.070381

# %%
df.sum()
# Out:
# Department          ABCDEF
# Male-Admitted         1126
# Male-Denied           1493
# Female-Admitted        557
# Female-Denied         1278
# Male-Ratio         2.16723
# Female-Ratio       2.50362
# dtype: object

# %%
pd.DataFrame(df.sum()).T
# Out:
#   Department Male-Admitted Male-Denied Female-Admitted Female-Denied  \
# 0     ABCDEF          1126        1493             557          1278
#
#   Male-Ratio Female-Ratio
# 0    2.16723      2.50362

# %%
df_university = pd.DataFrame(df.sum()).T

# %%
df_overall = pd.concat([df,df_university]) #concat 在下面加一行

# %%
df_overall
# Out:
#   Department Male-Admitted Male-Denied Female-Admitted Female-Denied  \
# 0          A           512         313              89            19
# 1          B           313         207              17             8
# 2          C           101         205             202           391
# 3          D           138         279             131           244
# 4          E            40         138              94           299
# 5          F            22         351              24           317
# 0     ABCDEF          1126        1493             557          1278
#
#   Male-Ratio Female-Ratio
# 0   0.620606     0.824074
# 1   0.601923         0.68
# 2   0.330065     0.340641
# 3   0.330935     0.349333
# 4   0.224719     0.239186
# 5  0.0589812    0.0703812
# 0    2.16723      2.50362

# %%
df
# Out:
#   Department  Male-Admitted  Male-Denied  Female-Admitted  Female-Denied  \
# 0          A            512          313               89             19
# 1          B            313          207               17              8
# 2          C            101          205              202            391
# 3          D            138          279              131            244
# 4          E             40          138               94            299
# 5          F             22          351               24            317
#
#    Male-Ratio  Female-Ratio
# 0    0.620606      0.824074
# 1    0.601923      0.680000
# 2    0.330065      0.340641
# 3    0.330935      0.349333
# 4    0.224719      0.239186
# 5    0.058981      0.070381

# %%
df_overall['Favour_Female'] = df['Female-Ratio'] > df['Male-Ratio']

# %%
df_overall
# Out:
#   Department Male-Admitted Male-Denied Female-Admitted Female-Denied  \
# 0          A           512         313              89            19
# 1          B           313         207              17             8
# 2          C           101         205             202           391
# 3          D           138         279             131           244
# 4          E            40         138              94           299
# 5          F            22         351              24           317
# 0     ABCDEF          1126        1493             557          1278
#
#   Male-Ratio Female-Ratio  Favour_Female
# 0   0.620606     0.824074           True
# 1   0.601923         0.68           True
# 2   0.330065     0.340641           True
# 3   0.330935     0.349333           True
# 4   0.224719     0.239186           True
# 5  0.0589812    0.0703812           True
# 0    2.16723      2.50362           True
